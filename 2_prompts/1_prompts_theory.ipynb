# %% [markdown]
# # Prompts:
#     - Prompts are the input instruction or queries given to the model to guide its output

# %% [markdown]
# #####  Prmpts type:
#     - text based
#     - Multimodel (Audio /Image / Video)

# %% [markdown]
# # Message Types:
#     - System msg(jo system ko hum blte hain ke polite ho kr reply dena  humanble reply dena ya huble rehna wagera wagera)
#     - Human msg(jo user dete hain AI ko)
#     - AI msg(jo AI answer deta)

# %% [markdown]
# ![image.png](attachment:image.png)
