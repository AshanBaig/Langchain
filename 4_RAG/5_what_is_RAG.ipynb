# %% [markdown]
# - Fine tunning means pretrained llm kodomain specific (small data pr retrain krna)
# - Fine tunning types:
#     - Supervised fine tunning (labeled data dete ap prompt and desired output)
#     - continue pretrain (unseper wise data dete hn llms already unsuperwise hote tw jabhi continue bol rhy)
#     - RLHF (reinforcement and )

# %% [markdown]
# ### How to fine tune??
# ![image.png](attachment:image.png)
#
# - Hellocination jo hoti like jaha llm atakta hy answer dne me ya ghlt deta fine tun ke zariye ye khtm kr skht like hum bol dain gye if u recieved such prompts so direclty say I dont know etc
# - but finetune computationally expensive hota hy and  required  technical expertise

# %% [markdown]
# # One more solution except fine tunning  is in context learning prompts me example dedo asy prompts ko few-sort prompts bolte
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - In context learning llm ki emergent property hy
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - indexing means external knowledge dena
# - retriveral specific jagha jaha data majod hy wo btana context dena
# - augmentation means prompt jab bnta dono c hezain mila kr
# - gnereration ans ata llms se

# %% [markdown]
# # Indexing
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Rtriveral
# ![image.png](attachment:image.png)

# %% [markdown]
# # Augmentation
# ![image.png](attachment:image.png)

# %% [markdown]
# # Generation
# ![image.png](attachment:image.png)
