# %% [markdown]
# ![image.png](attachment:46c2011e-a1be-4365-b7b3-562053ad2cab.png)

# %% [markdown]
# - Language model  chat bot bnane me help krte hain
#
#
# - Embadding model sematic search me help krte hain (vector rturn krta hy wohi embaded thing)

# %% [markdown]
# # 1. Language Model

# %% [markdown]
# ### 1.1 LLM (obselete ho gye hain ab)
#     - LLM --> Gneral purpose ke liye use hote like qurstion asnwr code likhwalo text generation summrization inpput string output string
# ### 1.2 Chat model
# ![image.png](attachment:92fc7bdd-1a0f-4ebf-a1c1-e28c4ca9ec28.png)

# %%
# Now start coding in vscode first we will work on LLMs

# %%
# temperature

# %% [markdown]
# ![image.png](attachment:image.png)
