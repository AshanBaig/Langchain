# %% [markdown]
# ![image.png](attachment:0fada9c2-135d-4f46-b2dd-d657a1e61321.png)
#
#     - Langchain ki trh bht si library hain inme se 1 llama bhi hy

# %% [markdown]
# # NLU Natural Language Understanding

# %% [markdown]
# ![image.png](attachment:41d1d7d9-4949-4a1b-9468-af6fe0892965.png)

# %% [markdown]
# ### 1 model: Basically if u want to talk with diff AI like open and cloud gimini so u have to wtie diff code for each of them
# -Lang change changes this u can easily do this in a single go this is model
# - Model Component is bascillly interface s sy ap kisi bhi company ke AI model se baat kr skhte ho simple

# %% [markdown]
# ### 2 Prompt = input
#     - Dynamic and reusbale prompt (1 msg jisme kch plac holder like tell me about {circket} in {fun} tone)
#     - Role basd prompts (YOur are senior doctor tell me about fever etc)
#     - few short prompting (kch example bta dena like this sentnce means fun this means angr this is moderate now new input dena or output le lena)

# %% [markdown]
# ### 3Chains = pipeline
# ![image.png](attachment:4ed5ea33-3f58-405c-bc1b-ef27751b849c.png)
#     - Agr ye mera work flow hy tw har 1 component mujhy khud call kra prega but chain would help us previous ka out put next ka input
# ![image.png](attachment:d5ace539-ff1b-4b2a-be6c-9564d2c3e295.png)
#     - Series bhi chlta and parallel bhi

# %% [markdown]
# ### 4 indexes
# #### indexes connect your application to your external model (pdf database )
#     - 4 main component hote hain
#         - doc loader
#         - text splitter
#         - vector store (jaha pr embaded data store hy)
#         - retiverors

# %% [markdown]
# ### 5 Memory
#     - LLM model are Stateless (har question new hy kisi ko previous question nhi pta like:)
#     - who is virat kohli (ans a jaye ga but if i ask next question how old is he ? so llm would say he who? LLM doesnt know previous question)

# %% [markdown]
# ### 5 AI agents
#     - It can do work (flight detail dene ke sath sath book bhi kr dega)
#     - AI agents ke pas reasoning capability hoti hy and tools ka acess
#         - tools calculator , whether api
#         - if I ask tell me today's karachi  temp mult by 3  so first karachi temp nikle ga by whather api and then calculator
#           me jayega 3 se mul hoga

# %% [markdown]
# - 1_model : from model folder
# - 2_prompts : from prompt folder

# %% [markdown]
# # Structured Ouput:

# %%
Unstructured output means jab hamara output text form me ho like koe structure nahoa every llm output is unstructured

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Agent use krte waqt bhi structured output zarori hota hy jese ke add 9 with 3 so it is textual info agent will convert it into tool usabl format jese ke 9,3,+  + krna hy 9,3 ko

# %% [markdown]
# - pehle llms and human ke beech me baat ho rhi thi
# - ab llm or system ke beech me baat ho rhi

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - kch LLMs  structured output generate kr skhte kch nhi langchain me dono ka solution hy

# %% [markdown]
# # 1 LLMS THAT CAN GENERATE STRUCTURED OUTPUT 3 tareke se krwa skhte hain
# - Typed dict
# - pydantic (fast api wagera)
# - json_schema  ( used when jab pora project 1 language m na bnaya ja rha ho)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - type dict bs btata hy kia type honi chaheye agr ghlt type dedo tw koe error nhi ata wo ghlt type le leta hy  baqi ka cod foder m hy 2.5 wle
# -  jo msla with_structured_ouput me tha wo solv krta hy pydantic
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Next Video 6
# ![image.png](attachment:image.png)

# %% [markdown]
# ouput parser se hum structured output le skhte hain kch llm khud se dete hain tw hum with structuredoutput func use krte hain kch nhi dete tw hum output parser use krte hain

# %% [markdown]
# ### 4 types of output parser
# - string  (string output ata direct result . content nhi krna prta hy)
# - json ( problem isme hum schema enforce nhi kr skhte like json object me agr hum 5 fruits mang rhy tw  ho skhta 1 key ho fruit or 5 fruit hn list me but we want fruit1 pehla fruit fruit2 dosra fruit)
# - structured output parser  (schema bna skhte ho but data validation nhi ho skhta hy like data type nhi bta skhte )
# - pydantic
# (ye basically return type hain )
# - csv bhi hota

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
