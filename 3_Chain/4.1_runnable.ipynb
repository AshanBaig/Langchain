# %% [markdown]
# # Runnables

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - agr hum 1 pdf reader bna rhy haain tw llm bs 1 jgha hy tw langchain ne baqi sb chezo ke liye alag alag helpr class bna di take hamara kaam ho ske (langchain kisi bhi llm se bht asani se baart kr skhta hy its advantage)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - langchain wlo ne dekha ke konsi konsi chezain reuse ho rhi hain like RAG me kch chezain hamesha ho rhi tw unhone us chez ka 1 func bna dia  Retrival wagera ka asy unhone chote chote bht se function bna diye jo sara 2,3 task 1 bari me perform kr dete hain
# - problem a gaya too many chains 1 tw code brh gaya + AI engineers ko msla hone lga sekhne me ke konsa kab sekhe sql chain api chain sb chains hain
# - at start when langchain build so wo is hisab se likhi nhi gai ke compoents apas me mil jain jese ke prompt.format krte result. content sb kch alag alag hy tw unhone chote chote components bnana start krdiye like llm+pormpt = llmchain
# - Runnable se ye set ho skhta tha

# %% [markdown]
# ![image.png](attachment:image.png)
# - Runnable common interface follow krte like invoke to give input take output
# - Runnable araam se connect ho jate hain like R1 ,R2 1 sath kr skhte R1 output is input for R2 work flow bnate hain  and ovrall again is work flow like  (R1-->R2  ,  R3 ---> R4)  tw ye 2 runnable hain dono apas me connect ho skhte

# %% [markdown]
# #### code nhi kra dekh lo if u needed bs ye btaya runnables hain kia 1 standardize method hy abstract class se inherit jisme har method ko invoke bnana hota hy take chain jab chle tw jitne bhi componenet de rhy chain ko us pr loop chle or chain[0,1,2].invoke() call hota rhy 1 ,1 kr ke

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Runanble passthrough jo input hota wohi output de deta hy faida???
# joke edxplanation wle case me humain joke nhi dikh rha tha Q ke wo ouptut prompt2 ka input bn gaya tha ab hum kia krain gye neche dekho

# %% [markdown]
# - joke generate krain gye ---> phr usko parallel 2 jagha bhej de gye 1 runnable passthrough Q kehumain joke chaheye and then joke explanation ke liye

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - python function ko execute krna ho but runnable bhi bnana ho take wo chain se connect ho jaye tw we use that thing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Runnable branch me tuple bhejte hain
# (conditoin1,chain1)
# (conditoin2,chain2)  # chain =  Runnable
# default cond # runnable lambda hota moslty

# %% [markdown]
# # LCEL (Langchain Excpression Language)
# -    They noticed Runnablesequence bht tezi se use ho rha hy tw pipe operator ko iske liye rkh dia
#     prompt | model | parser  asy likhte hum
